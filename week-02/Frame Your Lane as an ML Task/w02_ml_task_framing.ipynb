# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *This ML task is a **classification** problem. We aim to predict whether a user will convert (e.g., make a purchase, sign up for a service) or not. This is a classification task because the outcome is a discrete, binary label (convert/not convert).*

# %%
# This cell is for CODE (numbers, a query, a check).
# For a classification task, code here might involve checking the balance of classes in historical data or initial data exploration to confirm binary outcomes.
# Example: print(df['conversion_status'].value_counts())

# %% [markdown]
# ## 2. Target or proxy
#
# *The target variable is `conversion_status`, a binary label indicating whether a user completed a specific action (e.g., purchased an item, subscribed to a newsletter). This label comes from an **observed outcome**, recorded directly from user interactions within our system. There is no proxy being used; we are directly predicting the desired action.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Code here might involve verifying the target column's existence and its unique values.
# Example: print(df['conversion_status'].unique())

# %% [markdown]
# ## 3. Success metric
#
# *The primary success metric for this classification task is **F1-score**. This metric is chosen because it balances precision and recall, which is crucial when dealing with potentially imbalanced datasets (e.g., fewer conversions than non-conversions). A high F1-score (e.g., 0.75 or higher) would mean 'good' performance, indicating that our model effectively identifies positive cases without making too many false positive or false negative errors.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Code here could define helper functions for F1-score or load a sample dataset to demonstrate metric calculation.
# Example: from sklearn.metrics import f1_score

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *The unit of analysis is a `user session`. Each row in our dataframe represents a single user's interaction session on our platform, containing features describing that session (e.g., duration, number of pages viewed, device type) and the target variable (`conversion_status`) for that session.*

# %%
import pandas as pd

# This cell is for CODE (numbers, a query, a check).
# Create a dummy DataFrame representing the unit of analysis (user session)
# In a real scenario, this would involve loading data from your source (e.g., database, CSV).

data = {
    'session_id': [1, 2, 3, 4, 5],
    'user_id': ['A', 'B', 'A', 'C', 'B'],
    'session_duration_seconds': [120, 30, 180, 60, 240],
    'pages_viewed': [3, 1, 5, 2, 7],
    'device_type': ['mobile', 'desktop', 'mobile', 'tablet', 'desktop'],
    'conversion_status': [0, 0, 1, 0, 1]
}

df_unit_of_analysis = pd.DataFrame(data)

print("One row = one user session. Here's a sample:")
display(df_unit_of_analysis.head())
# Out:
# One row = one user session. Here's a sample:
#    session_id user_id  session_duration_seconds  pages_viewed device_type  \
# 0           1       A                       120             3      mobile
# 1           2       B                        30             1     desktop
# 2           3       A                       180             5      mobile
# 3           4       C                        60             2      tablet
# 4           5       B                       240             7     desktop
#
#    conversion_status
# 0                  0
# 1                  0
# 2                  1
# 3                  0
# 4                  1

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *ML beats a fixed rule here because the factors influencing user conversion are complex and exhibit non-linear relationships. A simple if-statement based on one or two features (e.g., `if session_duration > X then convert`) would miss the nuanced interactions between multiple variables like device type, referral source, time of day, pages viewed, and previous user history. Machine learning models can automatically discover these intricate patterns and weigh features appropriately to make more accurate and adaptive predictions, especially as user behavior evolves, which would be difficult to capture with manually defined rules.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Code here might demonstrate the complexity, e.g., by plotting feature distributions or correlations that are not easily separable with simple rules.
# Example: sns.pairplot(df_unit_of_analysis[['session_duration_seconds', 'pages_viewed', 'conversion_status']], hue='conversion_status')

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
